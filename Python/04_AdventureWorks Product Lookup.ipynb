# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("04_AdventureWorks Product Lookup.csv")
print(df)
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
df.head()
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 1         215                     31    HL-U509  Sport-100 Helmet, Black
# 2         218                     23  SO-B909-M   Mountain Bike Socks, M
# 3         219                     23  SO-B909-L   Mountain Bike Socks, L
# 4         220                     31  HL-U509-B   Sport-100 Helmet, Blue
#
#              ModelName                                 ProductDescription  \
# 0            Sport-100  Universal fit, well-vented, lightweight , snap...
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4            Sport-100  Universal fit, well-vented, lightweight , snap...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# ...

# %%
df.shape
# Out:
# (293, 11)

# %%
df.columns
# Out:
# Index(['ProductKey', 'ProductSubcategoryKey', 'ProductSKU', 'ProductName',
#        'ModelName', 'ProductDescription', 'ProductColor', 'ProductSize',
#        'ProductStyle', 'ProductCost', 'ProductPrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             293 non-null    int64
#  1   ProductSubcategoryKey  293 non-null    int64
#  2   ProductSKU             293 non-null    object
#  3   ProductName            293 non-null    object
#  4   ModelName              293 non-null    object
#  5   ProductDescription     293 non-null    object
#  6   ProductColor           243 non-null    object
#  7   ProductSize            293 non-null    object
#  8   ProductStyle           293 non-null    object
#  9   ProductCost            293 non-null    float64
#  10  ProductPrice           293 non-null    float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 25.3+ KB

# %%
df["ProductSize"].value_counts()
# Out:
# ProductSize
# 0     84
# 44    29
# 48    25
# 52    16
# 42    15
# 58    13
# 38    12
# L     11
# M     11
# 62    11
# 60    11
# 40    11
# 46    11
# S      9
# 50     9
# 54     9
# XL     3
# 56     2
# 70     1
# Name: count, dtype: int64

# %%
df["ProductSize"].unique()
# Out:
# array(['0', 'M', 'L', 'S', 'XL', '62', '44', '48', '52', '56', '58', '60',
#        '42', '46', '38', '40', '70', '50', '54'], dtype=object)

# %%
df.groupby("ProductSize")["ProductName"].count()
# Out:
# ProductSize
# 0     84
# 38    12
# 40    11
# 42    15
# 44    29
# 46    11
# 48    25
# 50     9
# 52    16
# 54     9
# 56     2
# 58    13
# 60    11
# 62    11
# 70     1
# L     11
# M     11
# S      9
# XL     3
# Name: ProductName, dtype: int64

# %%
df[df["ProductSize"]== "0"][["ProductName", "ProductSize"]]
# Out:
#                  ProductName ProductSize
# 0      Sport-100 Helmet, Red           0
# 1    Sport-100 Helmet, Black           0
# 4     Sport-100 Helmet, Blue           0
# 5               AWC Logo Cap           0
# 95                   LL Fork           0
# ..                       ...         ...
# 244              HL Crankset           0
# 245                    Chain           0
# 287        LL Bottom Bracket           0
# 288        ML Bottom Bracket           0
# 289        HL Bottom Bracket           0
#
# [84 rows x 2 columns]

# %%
df["ProductSize"] = df["ProductSize"].replace("0", "Not Applicable")

# %%
df
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
df.isnull().sum()
# Out:
# ProductKey                0
# ProductSubcategoryKey     0
# ProductSKU                0
# ProductName               0
# ModelName                 0
# ProductDescription        0
# ProductColor             50
# ProductSize               0
# ProductStyle              0
# ProductCost               0
# ProductPrice              0
# dtype: int64

# %%
df[df["ProductColor"].isnull()][["ProductName", "ProductColor"]]
# Out:
#                       ProductName ProductColor
# 95                        LL Fork          NaN
# 96                        ML Fork          NaN
# 97                        HL Fork          NaN
# 98                     LL Headset          NaN
# 99                     ML Headset          NaN
# 100                    HL Headset          NaN
# 101        LL Mountain Handlebars          NaN
# 102        ML Mountain Handlebars          NaN
# 103        HL Mountain Handlebars          NaN
# 104            LL Road Handlebars          NaN
# 105            ML Road Handlebars          NaN
# 106            HL Road Handlebars          NaN
# 136                    Cable Lock          NaN
# 137                      Minipump          NaN
# 138                 Mountain Pump          NaN
# 139  Taillights - Battery-Powered          NaN
# 140        Headlights - Dual-Beam          NaN
# 141     Headlights - Weatherproof          NaN
# 163         Water Bottle - 30 oz.          NaN
# ...

# %%
df["ProductColor"] = df["ProductColor"].fillna("NotApplicable")

# %%
df
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ProductKey"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             293 non-null    int64
#  1   ProductSubcategoryKey  293 non-null    int64
#  2   ProductSKU             293 non-null    object
#  3   ProductName            293 non-null    object
#  4   ModelName              293 non-null    object
#  5   ProductDescription     293 non-null    object
#  6   ProductColor           293 non-null    object
#  7   ProductSize            293 non-null    object
#  8   ProductStyle           293 non-null    object
#  9   ProductCost            293 non-null    float64
#  10  ProductPrice           293 non-null    float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 25.3+ KB

# %%
df["ProductColor"].value_counts()
# Out:
# ProductColor
# Black            88
# NotApplicable    50
# Red              37
# Silver           36
# Yellow           36
# Blue             26
# Multi             8
# Silver/Black      7
# White             4
# Grey              1
# Name: count, dtype: int64

# %%
df["ProductSize"].value_counts()
# Out:
# ProductSize
# Not Applicable    84
# 44                29
# 48                25
# 52                16
# 42                15
# 58                13
# 38                12
# L                 11
# M                 11
# 62                11
# 60                11
# 40                11
# 46                11
# S                  9
# 50                 9
# 54                 9
# XL                 3
# 56                 2
# 70                 1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        ProductKey  ProductSubcategoryKey  ProductCost  ProductPrice
# count  293.000000             293.000000   293.000000    293.000000
# mean   441.552901              12.283276   413.661009    714.437357
# std    108.064327               9.892831   517.611849    872.157258
# min    214.000000               1.000000     0.856500      2.290000
# 25%    354.000000               2.000000    31.724400     63.500000
# 50%    457.000000              12.000000   199.375700    333.420000
# 75%    533.000000              17.000000   601.743700   1003.910000
# max    606.000000              37.000000  2171.294200   3578.270000

# %%
df.to_excel("AdventureWorks Product Lookup.xlsx", index=False)

# %%
df["ProductStyle"].value_counts()
# Out:
# ProductStyle
# U    174
# 0     84
# W     28
# M      7
# Name: count, dtype: int64

# %%
df[df["ProductStyle"] == "0"][["ProductName", "ProductStyle"]]
# Out:
#                  ProductName ProductStyle
# 0      Sport-100 Helmet, Red            0
# 1    Sport-100 Helmet, Black            0
# 4     Sport-100 Helmet, Blue            0
# 95                   LL Fork            0
# 96                   ML Fork            0
# ..                       ...          ...
# 244              HL Crankset            0
# 245                    Chain            0
# 287        LL Bottom Bracket            0
# 288        ML Bottom Bracket            0
# 289        HL Bottom Bracket            0
#
# [84 rows x 2 columns]

# %%
df["ProductStyle"] = df["ProductStyle"].replace({
    "U" : "Universal",
    "0" : "Not Applicable",
    "W" : "Women",
    "M" :"Men",
})

# %%
df
# Out:
#      ProductKey  ProductSubcategoryKey  ProductSKU              ProductName  \
# 0           214                     31   HL-U509-R    Sport-100 Helmet, Red
# 1           215                     31     HL-U509  Sport-100 Helmet, Black
# 2           218                     23   SO-B909-M   Mountain Bike Socks, M
# 3           219                     23   SO-B909-L   Mountain Bike Socks, L
# 4           220                     31   HL-U509-B   Sport-100 Helmet, Blue
# ..          ...                    ...         ...                      ...
# 288         602                      5     BB-8107        ML Bottom Bracket
# 289         603                      5     BB-9108        HL Bottom Bracket
# 290         604                      2  BK-R19B-44       Road-750 Black, 44
# 291         605                      2  BK-R19B-48       Road-750 Black, 48
# 292         606                      2  BK-R19B-52       Road-750 Black, 52
#
# ...

# %%
df.to_excel("AdventureWorks Product Lookup.xlsx", index=False)

# %%
df["ProductKey"].nunique()
# Out:
# 293

# %%
df["ProductSubcategoryKey"].unique()
# Out:
# array([31, 23, 19, 21, 14, 12,  2,  1, 10, 11,  4, 17, 22, 35, 34, 36, 33,
#        24, 18, 20, 25, 28, 37, 26, 29, 30, 27, 32, 16,  9,  6, 15, 13,  8,
#         7,  3,  5])

# %%
missing_subcategories = (
    set(df["ProductSubcategoryKey"])
    - set(df["ProductSubcategoryKey"])
)

print(missing_subcategories)
# Out:
# set()
